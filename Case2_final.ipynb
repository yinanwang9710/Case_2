# %% [markdown]
# # CASE 2

# %% [markdown]
# ## 1. Setups & Import Data

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

# %%
df=pd.read_excel("Case_2_data.xlsx", sheet_name="evals_data")
df=df[~df.student_id.isin(df[df.duplicated(["student_id", "date"])].student_id.tolist())].reset_index(drop=True)
print("Numbers of Unique student_id: ",len(df.student_id.unique()))
df.head()
# Out:
# Numbers of Unique student_id:  8878
#    student_id       date program location  score_reading  score_writing  \
# 0      128368 2016-05-30  intake      NaN            741             64
# 1      128368 2016-06-24  skills   center            764             66
# 2      128374 2016-08-30  intake      NaN            561             48
# 3      128374 2016-09-22  skills   center            570             50
# 4      128375 2016-07-20  intake      NaN            627             64
#
#    score_mathNoCalc  score_mathCalc  Total Score     District  \
# 0               304             431         1540        Camas
# 1               320             446         1596        Camas
# 2               140             528         1277  Wilsonville
# 3               148             542         1310  Wilsonville
# 4               525             486         1702   Ridgefield
#
#    Reading_improvement  Writing_improvement  MathNoCalc_improvement  \
# 0                  NaN                  NaN                     NaN
# 1             0.031039             0.031250                0.052632
# 2                  NaN                  NaN                     NaN
# 3             0.016043             0.041667                0.057143
# 4                  NaN                  NaN                     NaN
#
#    MathCalc_improvement  total_improvement
# 0                   NaN                NaN
# 1              0.034803           0.036364
# 2                   NaN                NaN
# 3              0.026515           0.025842
# 4                   NaN                NaN

# %% [markdown]
# ## 2. Overall Performance

# %% [markdown]
# ### 2.1 Avg Intake Scores

# %%
avg_intake=df[["score_reading","score_writing","score_mathNoCalc","score_mathCalc","Total Score"]].mean()
avg_intake
# Out:
# score_reading        605.109523
# score_writing         51.025754
# score_mathNoCalc     493.888095
# score_mathCalc       560.755994
# Total Score         1710.779366
# dtype: float64

# %% [markdown]
# ### 2.2 Improvement Ranges

# %%
min_max_improv_prog=pd.concat([df[['program','Reading_improvement', 'Writing_improvement',
       'MathNoCalc_improvement', 'MathCalc_improvement', 'total_improvement']].groupby("program").min(),
df[['program','Reading_improvement', 'Writing_improvement',
       'MathNoCalc_improvement', 'MathCalc_improvement', 'total_improvement']].groupby("program").max()])
#min_max_improv_prog.to_csv("min_max_improv_prog.csv")
min_max_improv_prog
# Out:
#           Reading_improvement  Writing_improvement  MathNoCalc_improvement  \
# program
# intake                    NaN                  NaN                     NaN
# refresh             -0.034026            -0.055556               -0.025114
# skills              -0.024161            -0.125000               -0.024283
# tutoring            -0.010292             0.000000                0.003571
# intake                    NaN                  NaN                     NaN
# refresh              0.062583             0.100000                0.072093
# skills               0.076807             0.333333                0.094637
# tutoring             0.107981             0.500000                0.147239
#
#           MathCalc_improvement  total_improvement
# program
# intake                     NaN                NaN
# refresh              -0.033033          -0.015817
# skills               -0.026432          -0.011460
# tutoring             -0.001880           0.009944
# intake                     NaN                NaN
# refresh               0.075117           0.067600
# skills                0.250000           0.076246
# tutoring              0.114094           0.097185

# %% [markdown]
# ### 2.3 Improvements by Districts

# %%
dstrct_imprv=df.iloc[:,-6:].dropna().groupby('District').mean()
dstrct_imprv.to_csv("dstrct_imprv.csv")
dstrct_imprv
# Out:
#              Reading_improvement  Writing_improvement  MathNoCalc_improvement  \
# District
# Beaverton               0.021910             0.026841                0.036999
# Camas                   0.022373             0.026838                0.037782
# Lake Oswego             0.026147             0.031222                0.042058
# Ridgefield              0.020893             0.025853                0.036045
# Riverdale               0.020036             0.024666                0.034915
# Sherwood                0.022347             0.026510                0.037539
# St. Paul                0.022616             0.026838                0.037250
# Wilsonville             0.032191             0.036506                0.047477
#
#              MathCalc_improvement  total_improvement
# District
# Beaverton                0.027338           0.027937
# Camas                    0.027381           0.028415
# Lake Oswego              0.031375           0.032456
# Ridgefield               0.026487           0.027029
# Riverdale                0.025471           0.026023
# Sherwood                 0.027880           0.028414
# St. Paul                 0.027268           0.028248
# Wilsonville              0.036939           0.038030

# %% [markdown]
# ### 2.4 Improvements by Programs

# %%
prgrm_imprv=df[["program","Reading_improvement","Writing_improvement","MathNoCalc_improvement","MathCalc_improvement","total_improvement"]]\
    .dropna().groupby("program").mean()
prgrm_imprv
# Out:
#           Reading_improvement  Writing_improvement  MathNoCalc_improvement  \
# program
# refresh              0.009954             0.010930                0.017334
# skills               0.023639             0.028793                0.039704
# tutoring             0.037883             0.044243                0.057994
#
#           MathCalc_improvement  total_improvement
# program
# refresh               0.011847           0.012708
# skills                0.029600           0.030003
# tutoring              0.044165           0.045873

# %% [markdown]
# ###  2.5 Total Improvements Since the Beginning

# %%
start_end=pd.concat([df.loc[df.program=="intake",:"District"], df.groupby("student_id").apply(lambda x: x.loc[(x.date==max(x.date)),:"District"])])\
    .reset_index(drop=True)

total_improvement=start_end.groupby("student_id").apply(lambda x:\
    x.loc[x.date==max(x.date),"score_reading":"Total Score"].squeeze()/x.loc[x.date==min(x.date),"score_reading":"Total Score"].squeeze()-1)\
        .reset_index()
total_improvement=total_improvement.rename(columns={"score_reading": "reading", "score_writing": "writing","score_mathNoCalc":"mathNoCalc",\
    "score_mathCalc":"mathCalc","Total Score":"total"})
           
adding_loc_data=start_end.dropna(subset=["location"])[["student_id","location","District","date","program"]]
total_improvement=total_improvement.merge(adding_loc_data, how="left",on="student_id")
total_improvement.head()
# Out:
#    student_id   reading   writing  mathNoCalc  mathCalc     total location  \
# 0      128368  0.031039  0.031250    0.052632  0.034803  0.036364   center
# 1      128374  0.016043  0.041667    0.057143  0.026515  0.025842   center
# 2      128375  0.030303  0.046875    0.112381  0.088477  0.072855   center
# 3      128387  0.076446  0.068966    0.081081  0.099778  0.085582   center
# 4      128390  0.078464  0.040816    0.153716  0.070845  0.097264   online
#
#       District       date   program
# 0        Camas 2016-06-24    skills
# 1  Wilsonville 2016-09-22    skills
# 2   Ridgefield 2016-10-31    skills
# 3  Lake Oswego 2016-02-09  tutoring
# 4     St. Paul 2018-09-01  tutoring

# %% [markdown]
# ## 3. Regression Analysis

# %% [markdown]
# ### 3.1 Improvements by Each Program

# %% [markdown]
# #### Formatting Data

# %%
prg = pd.DataFrame(columns=["skills","tutoring","refresh","reading","writing","mathNoCalc","mathCalc","total"])
df=df.sort_values(by=['student_id', 'date'], ascending=True).reset_index(drop=True)
for i in range (1,len(df)): 
    if df.loc[i,"program"]  != "intake":
        prg.loc[i-1,df.loc[i,"program"]]=1
        prg.loc[i-1,"reading"]=df.loc[i,"score_reading"]/df.loc[i-1,"score_reading"]-1
        prg.loc[i-1,"writing"]=df.loc[i,"score_writing"]/df.loc[i-1,"score_writing"]-1
        prg.loc[i-1,"mathNoCalc"]=df.loc[i,"score_mathNoCalc"]/df.loc[i-1,"score_mathNoCalc"]-1
        prg.loc[i-1,"mathCalc"]=df.loc[i,"score_mathCalc"]/df.loc[i-1,"score_mathCalc"]-1
        prg.loc[i-1,"total"]=df.loc[i,"Total Score"]/df.loc[i-1,"Total Score"]-1
prg=prg.fillna(0)
prg.head()
# Out:
#    skills  tutoring  refresh   reading   writing  mathNoCalc  mathCalc  \
# 0       1         0        0  0.031039  0.031250    0.052632  0.034803
# 2       1         0        0  0.016043  0.041667    0.057143  0.026515
# 4       1         0        0  0.015949  0.000000    0.041905  0.030864
# 5       1         0        0  0.028257  0.062500    0.065814  0.049900
# 6       1         0        0 -0.013740 -0.014706    0.001715  0.005703
#
#       total
# 0  0.036364
# 2  0.025842
# 4  0.027615
# 5  0.047456
# 6 -0.003275

# %% [markdown]
# #### Improvement~Program Regression

# %%
for i in ["skills","tutoring","refresh"]:
    for j in ["reading","writing","mathNoCalc","mathCalc","total"]:
        reg=smf.ols("{}~{}".format(j,i), prg).fit()
        print("SUMMARY of {}_improvement ~ {}".format(j,i))
        print(reg.summary())
        print("\n")
        print("+"*100)
        print("\n")
# Out:
# SUMMARY of reading_improvement ~ skills
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                reading   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     24.39
# Date:                Thu, 11 Nov 2021   Prob (F-statistic):           7.96e-07
# Time:                        19:06:21   Log-Likelihood:                 45521.
# No. Observations:               17564   AIC:                        -9.104e+04
# Df Residuals:                   17562   BIC:                        -9.102e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0250      0.000    124.183      0.000       0.025       0.025
# skills        -0.0014      0.000     -4.938      0.000      -0.002      -0.001
# ==============================================================================
# Omnibus:                      998.813   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1244.250
# Skew:                           0.567   Prob(JB):                    6.52e-271
# Kurtosis:                       3.644   Cond. No.                         2.72
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# SUMMARY of writing_improvement ~ skills
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                writing   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                   0.04941
# Date:                Thu, 11 Nov 2021   Prob (F-statistic):              0.824
# Time:                        19:06:21   Log-Likelihood:                 41744.
# No. Observations:               17564   AIC:                        -8.348e+04
# Df Residuals:                   17562   BIC:                        -8.347e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0289      0.000    115.681      0.000       0.028       0.029
# skills      -7.56e-05      0.000     -0.222      0.824      -0.001       0.001
# ==============================================================================
# Omnibus:                     5975.045   Durbin-Watson:                   2.121
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           146761.461
# Skew:                           1.079   Prob(JB):                         0.00
# Kurtosis:                      16.996   Cond. No.                         2.72
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# SUMMARY of mathNoCalc_improvement ~ skills
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             mathNoCalc   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.892
# Date:                Thu, 11 Nov 2021   Prob (F-statistic):              0.169
# Time:                        19:06:21   Log-Likelihood:                 41462.
# No. Observations:               17564   AIC:                        -8.292e+04
# Df Residuals:                   17562   BIC:                        -8.290e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0392      0.000    154.699      0.000       0.039       0.040
# skills         0.0005      0.000      1.375      0.169      -0.000       0.001
# ==============================================================================
# Omnibus:                     1835.693   Durbin-Watson:                   1.980
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3077.926
# Skew:                           0.740   Prob(JB):                         0.00
# Kurtosis:                       4.419   Cond. No.                         2.72
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# SUMMARY of mathCalc_improvement ~ skills
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               mathCalc   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.445
# Date:                Thu, 11 Nov 2021   Prob (F-statistic):              0.229
# Time:                        19:06:21   Log-Likelihood:                 44493.
# No. Observations:               17564   AIC:                        -8.898e+04
# Df Residuals:                   17562   BIC:                        -8.897e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0292      0.000    137.067      0.000       0.029       0.030
# skills         0.0003      0.000      1.202      0.229      -0.000       0.001
# ==============================================================================
# Omnibus:                     1284.590   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2293.217
# Skew:                           0.539   Prob(JB):                         0.00
# Kurtosis:                       4.404   Cond. No.                         2.72
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# SUMMARY of total_improvement ~ skills
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  total   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     4.454
# Date:                Thu, 11 Nov 2021   Prob (F-statistic):             0.0348
# Time:                        19:06:21   Log-Likelihood:                 45997.
# No. Observations:               17564   AIC:                        -9.199e+04
# Df Residuals:                   17562   BIC:                        -9.198e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0306      0.000    156.049      0.000       0.030       0.031
# skills        -0.0006      0.000     -2.111      0.035      -0.001   -4.02e-05
# ==============================================================================
# Omnibus:                     1325.128   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1724.213
# Skew:                           0.675   Prob(JB):                         0.00
# Kurtosis:                       3.730   Cond. No.                         2.72
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# SUMMARY of reading_improvement ~ tutoring
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                reading   R-squared:                       0.187
# Model:                            OLS   Adj. R-squared:                  0.187
# Method:                 Least Squares   F-statistic:                     4028.
# Date:                Thu, 11 Nov 2021   Prob (F-statistic):               0.00
# Time:                        19:06:21   Log-Likelihood:                 47322.
# No. Observations:               17564   AIC:                        -9.464e+04
# Df Residuals:                   17562   BIC:                        -9.462e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0198      0.000    138.783      0.000       0.019       0.020
# tutoring       0.0181      0.000     63.468      0.000       0.018       0.019
# ==============================================================================
# Omnibus:                      404.795   Durbin-Watson:                   1.944
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              432.858
# Skew:                           0.384   Prob(JB):                     1.01e-94
# Kurtosis:                       3.055   Cond. No.                         2.49
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# SUMMARY of writing_improvement ~ tutoring
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                writing   R-squared:                       0.156
# Model:                            OLS   Adj. R-squared:                  0.156
# Method:                 Least Squares   F-statistic:                     3239.
# Date:                Thu, 11 Nov 2021   Prob (F-statistic):               0.00
# Time:                        19:06:21   Log-Likelihood:                 43230.
# No. Observations:               17564   AIC:                        -8.646e+04
# Df Residuals:                   17562   BIC:                        -8.644e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0237      0.000    132.024      0.000       0.023       0.024
# tutoring       0.0205      0.000     56.910      0.000       0.020       0.021
# ==============================================================================
# Omnibus:                     6411.725   Durbin-Watson:                   2.081
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           224366.136
# Skew:                           1.096   Prob(JB):                         0.00
# Kurtosis:                      20.372   Cond. No.                         2.49
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# SUMMARY of mathNoCalc_improvement ~ tutoring
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             mathNoCalc   R-squared:                       0.217
# Model:                            OLS   Adj. R-squared:                  0.217
# Method:                 Least Squares   F-statistic:                     4878.
# Date:                Thu, 11 Nov 2021   Prob (F-statistic):               0.00
# Time:                        19:06:21   Log-Likelihood:                 43614.
# No. Observations:               17564   AIC:                        -8.722e+04
# Df Residuals:                   17562   BIC:                        -8.721e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0334      0.000    189.726      0.000       0.033       0.034
# tutoring       0.0246      0.000     69.842      0.000       0.024       0.025
# ==============================================================================
# Omnibus:                      404.598   Durbin-Watson:                   1.901
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              432.950
# Skew:                           0.377   Prob(JB):                     9.69e-95
# Kurtosis:                       3.156   Cond. No.                         2.49
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# SUMMARY of mathCalc_improvement ~ tutoring
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               mathCalc   R-squared:                       0.194
# Model:                            OLS   Adj. R-squared:                  0.194
# Method:                 Least Squares   F-statistic:                     4236.
# Date:                Thu, 11 Nov 2021   Prob (F-statistic):               0.00
# Time:                        19:06:21   Log-Likelihood:                 46389.
# No. Observations:               17564   AIC:                        -9.277e+04
# Df Residuals:                   17562   BIC:                        -9.276e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0246      0.000    163.625      0.000       0.024       0.025
# tutoring       0.0196      0.000     65.084      0.000       0.019       0.020
# ==============================================================================
# Omnibus:                     1044.758   Durbin-Watson:                   1.922
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2176.877
# Skew:                           0.410   Prob(JB):                         0.00
# Kurtosis:                       4.517   Cond. No.                         2.49
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# SUMMARY of total_improvement ~ tutoring
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  total   R-squared:                       0.259
# Model:                            OLS   Adj. R-squared:                  0.259
# Method:                 Least Squares   F-statistic:                     6141.
# Date:                Thu, 11 Nov 2021   Prob (F-statistic):               0.00
# Time:                        19:06:21   Log-Likelihood:                 48628.
# No. Observations:               17564   AIC:                        -9.725e+04
# Df Residuals:                   17562   BIC:                        -9.724e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0251      0.000    189.903      0.000       0.025       0.025
# tutoring       0.0208      0.000     78.362      0.000       0.020       0.021
# ==============================================================================
# Omnibus:                      498.869   Durbin-Watson:                   1.893
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              511.941
# Skew:                           0.396   Prob(JB):                    6.81e-112
# Kurtosis:                       2.728   Cond. No.                         2.49
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# SUMMARY of reading_improvement ~ refresh
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                reading   R-squared:                       0.169
# Model:                            OLS   Adj. R-squared:                  0.169
# Method:                 Least Squares   F-statistic:                     3561.
# Date:                Thu, 11 Nov 2021   Prob (F-statistic):               0.00
# Time:                        19:06:21   Log-Likelihood:                 47130.
# No. Observations:               17564   AIC:                        -9.426e+04
# Df Residuals:                   17562   BIC:                        -9.424e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0281      0.000    200.054      0.000       0.028       0.028
# refresh       -0.0182      0.000    -59.672      0.000      -0.019      -0.018
# ==============================================================================
# Omnibus:                     1307.315   Durbin-Watson:                   2.067
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1787.811
# Skew:                           0.642   Prob(JB):                         0.00
# Kurtosis:                       3.892   Cond. No.                         2.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# SUMMARY of writing_improvement ~ refresh
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                writing   R-squared:                       0.172
# Model:                            OLS   Adj. R-squared:                  0.172
# Method:                 Least Squares   F-statistic:                     3642.
# Date:                Thu, 11 Nov 2021   Prob (F-statistic):               0.00
# Time:                        19:06:21   Log-Likelihood:                 43399.
# No. Observations:               17564   AIC:                        -8.679e+04
# Df Residuals:                   17562   BIC:                        -8.678e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0337      0.000    193.587      0.000       0.033       0.034
# refresh       -0.0227      0.000    -60.351      0.000      -0.023      -0.022
# ==============================================================================
# Omnibus:                     7253.510   Durbin-Watson:                   2.177
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           285915.330
# Skew:                           1.295   Prob(JB):                         0.00
# Kurtosis:                      22.595   Cond. No.                         2.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# SUMMARY of mathNoCalc_improvement ~ refresh
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             mathNoCalc   R-squared:                       0.255
# Model:                            OLS   Adj. R-squared:                  0.255
# Method:                 Least Squares   F-statistic:                     6004.
# Date:                Thu, 11 Nov 2021   Prob (F-statistic):               0.00
# Time:                        19:06:21   Log-Likelihood:                 44044.
# No. Observations:               17564   AIC:                        -8.808e+04
# Df Residuals:                   17562   BIC:                        -8.807e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0455      0.000    271.254      0.000       0.045       0.046
# refresh       -0.0281      0.000    -77.485      0.000      -0.029      -0.027
# ==============================================================================
# Omnibus:                     2835.508   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6091.219
# Skew:                           0.958   Prob(JB):                         0.00
# Kurtosis:                       5.156   Cond. No.                         2.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# SUMMARY of mathCalc_improvement ~ refresh
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               mathCalc   R-squared:                       0.227
# Model:                            OLS   Adj. R-squared:                  0.227
# Method:                 Least Squares   F-statistic:                     5154.
# Date:                Thu, 11 Nov 2021   Prob (F-statistic):               0.00
# Time:                        19:06:21   Log-Likelihood:                 46752.
# No. Observations:               17564   AIC:                        -9.350e+04
# Df Residuals:                   17562   BIC:                        -9.348e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0342      0.000    237.977      0.000       0.034       0.034
# refresh       -0.0224      0.000    -71.793      0.000      -0.023      -0.022
# ==============================================================================
# Omnibus:                     1961.311   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4954.384
# Skew:                           0.647   Prob(JB):                         0.00
# Kurtosis:                       5.258   Cond. No.                         2.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# SUMMARY of total_improvement ~ refresh
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  total   R-squared:                       0.268
# Model:                            OLS   Adj. R-squared:                  0.268
# Method:                 Least Squares   F-statistic:                     6435.
# Date:                Thu, 11 Nov 2021   Prob (F-statistic):               0.00
# Time:                        19:06:21   Log-Likelihood:                 48737.
# No. Observations:               17564   AIC:                        -9.747e+04
# Df Residuals:                   17562   BIC:                        -9.745e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0350      0.000    272.803      0.000       0.035       0.035
# refresh       -0.0223      0.000    -80.221      0.000      -0.023      -0.022
# ==============================================================================
# Omnibus:                     2308.961   Durbin-Watson:                   2.053
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3793.180
# Skew:                           0.905   Prob(JB):                         0.00
# Kurtosis:                       4.381   Cond. No.                         2.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ### 3.2 Improvement by Online/Center

# %% [markdown]
# online=0; center=1

# %% [markdown]
# #### Formatting Data

# %%
def check_mix_loc(df):
    df=df[(df.program!="skills")&(df.program!="intake")  & (pd.DatetimeIndex(df['date']).year>2017)]
    if (("center" in df.location.tolist()) & ("center" in df.location.tolist())):
        return df
mix_loc=df.groupby("student_id").apply(lambda x: check_mix_loc(x)).reset_index(drop=True)
mix_loc.loc[mix_loc.location=="center","location"]=1
mix_loc.loc[mix_loc.location=="online","location"]=0
mix_loc.head()
# Out:
#    student_id       date   program location  score_reading  score_writing  \
# 0      128398 2018-12-16   refresh        1            530             66
# 1      128437 2018-04-27  tutoring        1            696             69
# 2      128605 2018-09-18  tutoring        1            733             63
# 3      128605 2018-12-08   refresh        0            771             65
# 4      128624 2018-11-27  tutoring        1            724             59
#
#    score_mathNoCalc  score_mathCalc  Total Score     District  \
# 0               348             548         1492     St. Paul
# 1               390             524         1679  Wilsonville
# 2               677             638         2111     St. Paul
# 3               719             670         2225     St. Paul
# 4               570             731         2084    Beaverton
#
#    Reading_improvement  Writing_improvement  MathNoCalc_improvement  \
# 0             0.001890             0.000000                0.011628
# 1             0.070769             0.078125                0.104816
# 2             0.071637             0.086207                0.090177
# 3             0.014474             0.015625                0.030086
# 4             0.072593             0.072727                0.077505
#
#    MathCalc_improvement  total_improvement
# 0              0.020484           0.010840
# 1              0.087137           0.083925
# 2              0.065109           0.075943
# 3              0.022901           0.022049
# 4              0.067153           0.072016

# %% [markdown]
# #### Overall_Improvement~Online/Center

# %%
for i in ['Reading_improvement', 'Writing_improvement',
       'MathNoCalc_improvement', 'MathCalc_improvement', 'total_improvement']:
    print("SUMMARY of {} ~ location".format(i))
    reg_refresh=smf.ols("{}~location".format(i),mix_loc).fit()
    print(reg_refresh.summary())
    print("\n")
    print("+"*100)
    print("\n")
# Out:
# SUMMARY of Reading_improvement ~ location
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     Reading_improvement   R-squared:                       0.090
# Model:                             OLS   Adj. R-squared:                  0.090
# Method:                  Least Squares   F-statistic:                     154.3
# Date:                 Thu, 11 Nov 2021   Prob (F-statistic):           7.78e-34
# Time:                         19:06:29   Log-Likelihood:                 3300.1
# No. Observations:                 1553   AIC:                            -6596.
# Df Residuals:                     1551   BIC:                            -6586.
# Df Model:                            1
# Covariance Type:             nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.0262      0.001     18.981      0.000       0.024       0.029
# location[T.1]     0.0203      0.002     12.420      0.000       0.017       0.023
# ==============================================================================
# Omnibus:                      506.290   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              116.699
# Skew:                          -0.414   Prob(JB):                     4.56e-26
# Kurtosis:                       1.943   Cond. No.                         3.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# SUMMARY of Writing_improvement ~ location
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     Writing_improvement   R-squared:                       0.081
# Model:                             OLS   Adj. R-squared:                  0.081
# Method:                  Least Squares   F-statistic:                     137.4
# Date:                 Thu, 11 Nov 2021   Prob (F-statistic):           1.81e-30
# Time:                         19:06:29   Log-Likelihood:                 3080.3
# No. Observations:                 1553   AIC:                            -6157.
# Df Residuals:                     1551   BIC:                            -6146.
# Df Model:                            1
# Covariance Type:             nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.0295      0.002     18.527      0.000       0.026       0.033
# location[T.1]     0.0220      0.002     11.722      0.000       0.018       0.026
# ==============================================================================
# Omnibus:                       20.130   Durbin-Watson:                   2.048
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.296
# Skew:                          -0.239   Prob(JB):                     6.46e-05
# Kurtosis:                       2.738   Cond. No.                         3.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# SUMMARY of MathNoCalc_improvement ~ location
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     MathNoCalc_improvement   R-squared:                       0.010
# Model:                                OLS   Adj. R-squared:                  0.009
# Method:                     Least Squares   F-statistic:                     15.56
# Date:                    Thu, 11 Nov 2021   Prob (F-statistic):           8.33e-05
# Time:                            19:06:29   Log-Likelihood:                 2909.0
# No. Observations:                    1553   AIC:                            -5814.
# Df Residuals:                        1551   BIC:                            -5803.
# Df Model:                               1
# Covariance Type:                nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.0507      0.002     28.533      0.000       0.047       0.054
# location[T.1]     0.0083      0.002      3.945      0.000       0.004       0.012
# ==============================================================================
# Omnibus:                     1367.121   Durbin-Watson:                   2.019
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              100.356
# Skew:                          -0.140   Prob(JB):                     1.61e-22
# Kurtosis:                       1.787   Cond. No.                         3.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# SUMMARY of MathCalc_improvement ~ location
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     MathCalc_improvement   R-squared:                       0.085
# Model:                              OLS   Adj. R-squared:                  0.084
# Method:                   Least Squares   F-statistic:                     144.2
# Date:                  Thu, 11 Nov 2021   Prob (F-statistic):           7.75e-32
# Time:                          19:06:29   Log-Likelihood:                 3202.4
# No. Observations:                  1553   AIC:                            -6401.
# Df Residuals:                      1551   BIC:                            -6390.
# Df Model:                             1
# Covariance Type:              nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.0302      0.001     20.532      0.000       0.027       0.033
# location[T.1]     0.0209      0.002     12.010      0.000       0.017       0.024
# ==============================================================================
# Omnibus:                      681.648   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              130.091
# Skew:                          -0.441   Prob(JB):                     5.64e-29
# Kurtosis:                       1.890   Cond. No.                         3.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# SUMMARY of total_improvement ~ location
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      total_improvement   R-squared:                       0.060
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     99.61
# Date:                Thu, 11 Nov 2021   Prob (F-statistic):           8.86e-23
# Time:                        19:06:29   Log-Likelihood:                 3222.5
# No. Observations:                1553   AIC:                            -6441.
# Df Residuals:                    1551   BIC:                            -6430.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.0346      0.001     23.829      0.000       0.032       0.037
# location[T.1]     0.0171      0.002      9.981      0.000       0.014       0.020
# ==============================================================================
# Omnibus:                    23443.618   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              171.248
# Skew:                          -0.429   Prob(JB):                     6.52e-38
# Kurtosis:                       1.618   Cond. No.                         3.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# #### Seperate Overall_Improvement~Online/Center by Programs(Refresh/Tutoring)

# %%
df_refresh=mix_loc[mix_loc.program=="refresh"]
df_tutoring=mix_loc[mix_loc.program=="tutoring"]
for i in ['Reading_improvement', 'Writing_improvement',
       'MathNoCalc_improvement', 'MathCalc_improvement', 'total_improvement']:
    
    print("SUMMARY of {} ~ location in REFRESH".format(i))
    reg_refresh=smf.ols("{}~location".format(i), df_refresh).fit()
    print(reg_refresh.summary())
    print("\n")
    print("+"*100)
    print("\n")

    print("SUMMARY of {} ~ location in TUTORING".format(i))
    reg_tutoring=smf.ols("{}~location".format(i), df_tutoring).fit()
    print(reg_tutoring.summary())
    print("\n")
    print("+"*100)
    print("\n")
# Out:
# SUMMARY of Reading_improvement ~ location in REFRESH
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     Reading_improvement   R-squared:                       0.036
# Model:                             OLS   Adj. R-squared:                  0.034
# Method:                  Least Squares   F-statistic:                     24.28
# Date:                 Thu, 11 Nov 2021   Prob (F-statistic):           1.05e-06
# Time:                         19:06:29   Log-Likelihood:                 1961.8
# No. Observations:                  657   AIC:                            -3920.
# Df Residuals:                      655   BIC:                            -3911.
# Df Model:                            1
# Covariance Type:             nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.0121      0.001     15.957      0.000       0.011       0.014
# location[T.1]    -0.0048      0.001     -4.928      0.000      -0.007      -0.003
# ==============================================================================
# Omnibus:                       15.775   Durbin-Watson:                   1.893
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.088
# Skew:                           0.263   Prob(JB):                     4.34e-05
# Kurtosis:                       3.676   Cond. No.                         2.93
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# SUMMARY of Reading_improvement ~ location in TUTORING
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     Reading_improvement   R-squared:                       0.323
# Model:                             OLS   Adj. R-squared:                  0.322
# Method:                  Least Squares   F-statistic:                     425.7
# Date:                 Thu, 11 Nov 2021   Prob (F-statistic):           1.18e-77
# Time:                         19:06:29   Log-Likelihood:                 2698.2
# No. Observations:                  896   AIC:                            -5392.
# Df Residuals:                      894   BIC:                            -5383.
# Df Model:                            1
# Covariance Type:             nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.0473      0.001     52.637      0.000       0.046       0.049
# location[T.1]     0.0207      0.001     20.631      0.000       0.019       0.023
# ==============================================================================
# Omnibus:                        0.938   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.626   Jarque-Bera (JB):                0.804
# Skew:                          -0.017   Prob(JB):                        0.669
# Kurtosis:                       3.143   Cond. No.                         4.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# SUMMARY of Writing_improvement ~ location in REFRESH
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     Writing_improvement   R-squared:                       0.029
# Model:                             OLS   Adj. R-squared:                  0.028
# Method:                  Least Squares   F-statistic:                     19.58
# Date:                 Thu, 11 Nov 2021   Prob (F-statistic):           1.13e-05
# Time:                         19:06:29   Log-Likelihood:                 1791.6
# No. Observations:                  657   AIC:                            -3579.
# Df Residuals:                      655   BIC:                            -3570.
# Df Model:                            1
# Covariance Type:             nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.0138      0.001     14.071      0.000       0.012       0.016
# location[T.1]    -0.0056      0.001     -4.425      0.000      -0.008      -0.003
# ==============================================================================
# Omnibus:                       12.006   Durbin-Watson:                   2.038
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               14.842
# Skew:                           0.217   Prob(JB):                     0.000598
# Kurtosis:                       3.595   Cond. No.                         2.93
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# SUMMARY of Writing_improvement ~ location in TUTORING
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     Writing_improvement   R-squared:                       0.223
# Model:                             OLS   Adj. R-squared:                  0.222
# Method:                  Least Squares   F-statistic:                     256.0
# Date:                 Thu, 11 Nov 2021   Prob (F-statistic):           7.25e-51
# Time:                         19:06:29   Log-Likelihood:                 2399.1
# No. Observations:                  896   AIC:                            -4794.
# Df Residuals:                      894   BIC:                            -4785.
# Df Model:                            1
# Covariance Type:             nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.0529      0.001     42.133      0.000       0.050       0.055
# location[T.1]     0.0224      0.001     16.001      0.000       0.020       0.025
# ==============================================================================
# Omnibus:                      308.462   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7438.833
# Skew:                           0.997   Prob(JB):                         0.00
# Kurtosis:                      16.974   Cond. No.                         4.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# SUMMARY of MathNoCalc_improvement ~ location in REFRESH
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     MathNoCalc_improvement   R-squared:                       0.059
# Model:                                OLS   Adj. R-squared:                  0.058
# Method:                     Least Squares   F-statistic:                     41.32
# Date:                    Thu, 11 Nov 2021   Prob (F-statistic):           2.49e-10
# Time:                            19:06:29   Log-Likelihood:                 1910.0
# No. Observations:                     657   AIC:                            -3816.
# Df Residuals:                         655   BIC:                            -3807.
# Df Model:                               1
# Covariance Type:                nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.0205      0.001     25.112      0.000       0.019       0.022
# location[T.1]    -0.0068      0.001     -6.428      0.000      -0.009      -0.005
# ==============================================================================
# Omnibus:                        5.379   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.068   Jarque-Bera (JB):                5.386
# Skew:                           0.172   Prob(JB):                       0.0677
# Kurtosis:                       3.279   Cond. No.                         2.93
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# SUMMARY of MathNoCalc_improvement ~ location in TUTORING
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     MathNoCalc_improvement   R-squared:                       0.096
# Model:                                OLS   Adj. R-squared:                  0.095
# Method:                     Least Squares   F-statistic:                     95.07
# Date:                    Thu, 11 Nov 2021   Prob (F-statistic):           2.05e-21
# Time:                            19:06:29   Log-Likelihood:                 2527.3
# No. Observations:                     896   AIC:                            -5051.
# Df Residuals:                         894   BIC:                            -5041.
# Df Model:                               1
# Covariance Type:                nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.0956      0.001     87.932      0.000       0.094       0.098
# location[T.1]    -0.0118      0.001     -9.750      0.000      -0.014      -0.009
# ==============================================================================
# Omnibus:                       52.441   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.691
# Skew:                          -0.496   Prob(JB):                     9.96e-17
# Kurtosis:                       3.995   Cond. No.                         4.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# SUMMARY of MathCalc_improvement ~ location in REFRESH
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     MathCalc_improvement   R-squared:                       0.049
# Model:                              OLS   Adj. R-squared:                  0.047
# Method:                   Least Squares   F-statistic:                     33.65
# Date:                  Thu, 11 Nov 2021   Prob (F-statistic):           1.03e-08
# Time:                          19:06:29   Log-Likelihood:                 1948.3
# No. Observations:                   657   AIC:                            -3893.
# Df Residuals:                       655   BIC:                            -3884.
# Df Model:                             1
# Covariance Type:              nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.0146      0.001     18.980      0.000       0.013       0.016
# location[T.1]    -0.0058      0.001     -5.801      0.000      -0.008      -0.004
# ==============================================================================
# Omnibus:                       15.669   Durbin-Watson:                   2.101
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.411
# Skew:                           0.253   Prob(JB):                     3.70e-05
# Kurtosis:                       3.699   Cond. No.                         2.93
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# SUMMARY of MathCalc_improvement ~ location in TUTORING
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     MathCalc_improvement   R-squared:                       0.335
# Model:                              OLS   Adj. R-squared:                  0.335
# Method:                   Least Squares   F-statistic:                     451.2
# Date:                  Thu, 11 Nov 2021   Prob (F-statistic):           2.23e-81
# Time:                          19:06:29   Log-Likelihood:                 2717.9
# No. Observations:                   896   AIC:                            -5432.
# Df Residuals:                       894   BIC:                            -5422.
# Df Model:                             1
# Covariance Type:              nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.0534      0.001     60.718      0.000       0.052       0.055
# location[T.1]     0.0208      0.001     21.240      0.000       0.019       0.023
# ==============================================================================
# Omnibus:                       42.507   Durbin-Watson:                   1.842
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              130.200
# Skew:                          -0.086   Prob(JB):                     5.34e-29
# Kurtosis:                       4.860   Cond. No.                         4.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# SUMMARY of total_improvement ~ location in REFRESH
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      total_improvement   R-squared:                       0.084
# Model:                            OLS   Adj. R-squared:                  0.083
# Method:                 Least Squares   F-statistic:                     60.36
# Date:                Thu, 11 Nov 2021   Prob (F-statistic):           3.06e-14
# Time:                        19:06:29   Log-Likelihood:                 2145.6
# No. Observations:                 657   AIC:                            -4287.
# Df Residuals:                     655   BIC:                            -4278.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.0154      0.001     26.999      0.000       0.014       0.017
# location[T.1]    -0.0057      0.001     -7.769      0.000      -0.007      -0.004
# ==============================================================================
# Omnibus:                       67.525   Durbin-Watson:                   1.951
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              152.305
# Skew:                           0.579   Prob(JB):                     8.46e-34
# Kurtosis:                       5.055   Cond. No.                         2.93
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# SUMMARY of total_improvement ~ location in TUTORING
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      total_improvement   R-squared:                       0.249
# Model:                            OLS   Adj. R-squared:                  0.249
# Method:                 Least Squares   F-statistic:                     297.1
# Date:                Thu, 11 Nov 2021   Prob (F-statistic):           1.08e-57
# Time:                        19:06:29   Log-Likelihood:                 3055.0
# No. Observations:                 896   AIC:                            -6106.
# Df Residuals:                     894   BIC:                            -6096.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.0632      0.001    104.664      0.000       0.062       0.064
# location[T.1]     0.0116      0.001     17.235      0.000       0.010       0.013
# ==============================================================================
# Omnibus:                        3.956   Durbin-Watson:                   1.789
# Prob(Omnibus):                  0.138   Jarque-Bera (JB):                3.854
# Skew:                           0.159   Prob(JB):                        0.146
# Kurtosis:                       3.051   Cond. No.                         4.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ### 3.3 Improvement by Programs Taken

# %%
prg_comp = pd.DataFrame(columns=["student_id","skills","tutoring","refresh"])
for i in df.student_id:
    prg_rcd=df.loc[df.student_id==i,"program"].tolist()
    prg_comp.loc[i,"student_id"]=i
    prg_comp.loc[i,"skills"]=int("skills" in prg_rcd)
    prg_comp.loc[i,"tutoring"]=int("tutoring" in prg_rcd)
    prg_comp.loc[i,"refresh"]=int("refresh" in prg_rcd)
prg_comp=prg_comp.merge(total_improvement.iloc[:,:-4], how="left", on ="student_id")
#prg_comp.to_csv("prg_comp.csv")
prg_comp
# Out:
#      student_id skills tutoring refresh   reading   writing  mathNoCalc  \
# 0        128368      1        0       0  0.031039  0.031250    0.052632
# 1        128374      1        0       0  0.016043  0.041667    0.057143
# 2        128375      1        0       0  0.030303  0.046875    0.112381
# 3        128387      0        1       0  0.076446  0.068966    0.081081
# 4        128390      1        1       0  0.078464  0.040816    0.153716
# ...         ...    ...      ...     ...       ...       ...         ...
# 8873     179191      1        1       0  0.067083  0.115385    0.103118
# 8874     179210      1        0       1 -0.001618  0.052632    0.049724
# 8875     179235      1        1       0  0.112853  0.170732    0.165165
# 8876     179239      0        1       0  0.066667  0.106061    0.115132
# 8877     179258      1        0       1  0.043344  0.075000    0.070447
#
#       mathCalc     total
# 0     0.034803  0.036364
# 1     0.026515  0.025842
# 2     0.088477  0.072855
# 3     0.099778  0.085582
# 4     0.070845  0.097264
# ...        ...       ...
# 8873  0.084677  0.083437
# 8874  0.069277  0.039851
# 8875  0.163793  0.140441
# 8876  0.116236  0.094784
# 8877  0.074483  0.063221
#
# [8878 rows x 9 columns]
